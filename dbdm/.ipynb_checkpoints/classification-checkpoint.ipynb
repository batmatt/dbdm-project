# %%
import pandas as pd

with open('../data/kym.json', 'r') as file:
    data = pd.read_json(file)

data.head()
# Out:
#                               title  \
# 0  This is Relevant To My Interests
# 1                        ROFLcopter
# 2                Bitches Don't Know
# 3               Leave Britney Alone
# 4                            O RLY?
#
#                                                  url  last_update_source  \
# 0  https://knowyourmeme.com/memes/this-is-relevan...          1547002898
# 1          https://knowyourmeme.com/memes/roflcopter          1591400337
# 2   https://knowyourmeme.com/memes/bitches-dont-know          1607986999
# 3  https://knowyourmeme.com/memes/leave-britney-a...          1613129339
# 4               https://knowyourmeme.com/memes/o-rly          1615643899
#
#   category                                 template_image_url  \
# 0     Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 1     Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 2     Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 3     Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 4     Meme  https://i.kym-cdn.com/entries/icons/original/0...
#
#                                                 meta  \
# 0  {'og:title': 'This is Relevant To My Interests...
# 1  {'og:title': 'ROFLcopter', 'og:site_name': 'Kn...
# 2  {'og:title': 'Bitches Don't Know', 'og:site_na...
# 3  {'og:title': 'Leave Britney Alone', 'og:site_n...
# 4  {'og:title': 'O RLY?', 'og:site_name': 'Know Y...
#
#                                                   ld         added  \
# 0  {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 1  {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 2  {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 3  {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 4  {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
#
#                                              details  \
# 0  {'status': 'confirmed', 'origin': 'I Can Has C...
# 1  {'status': 'confirmed', 'origin': 'Warcraft II...
# 2  {'status': 'confirmed', 'origin': 'MySpace', '...
# 3  {'status': 'confirmed', 'origin': 'YouTube', '...
# 4  {'status': 'confirmed', 'origin': 'Something A...
#
#                                              content  \
# 0  {'about': {'text': ['"This is Relevant To My I...
# 1  {'about': {'text': ['ROFLcopter is an Internet...
# 2  {'about': {'text': ['Bitches Don't Know is an ...
# 3  {'about': {'text': ['"Leave Britney Alone" is ...
# 4  {'about': {'text': ['O RLY is internet slang f...
#
#                                                 tags  \
# 0  [image macros, comment, comments, approval, im...
# 1   [ascii, animated gif, rofl, acronym, initialism]
# 2  [myspace, 4chan, parody, know, bitches, dont, ...
# 3  [youtube, rant, britney spears, response, frea...
# 4  [image macro, owl, orly, o rly, negative, some...
#
#                                additional_references  \
# 0                                                 {}
# 1  {'Encyclopedia Dramatica': 'https://encycloped...
# 2  {'Facebook,': 'https://www.facebook.com/search...
# 3  {'Wikipedia': 'https://en.wikipedia.org/wiki/C...
# 4  {'Meme Generator,': 'https://imgflip.com/meme/...
#
#                                 search_keywords  \
# 0        [\"This is relevant to my interests\"]
# 1                                  [roflcopter]
# 2                          [bitches don't know]
# 3  [\"leave britney alone\", \"chris crocker\"]
# 4                                   [\"o rly\"]
#
#                                               parent  \
# 0                                                NaN
# 1           https://knowyourmeme.com/memes/lol-ascii
# 2                                                NaN
# 3  https://knowyourmeme.com/memes/people/chris-cr...
# 4  https://knowyourmeme.com/memes/lolspeak-chanspeak
#
#                                             siblings  \
# 0                                                NaN
# 1  [https://knowyourmeme.com/memes/lollerskates, ...
# 2                                                NaN
# 3  [https://knowyourmeme.com/memes/leave-britney-...
# 4  [https://knowyourmeme.com/memes/normie, https:...
#
#                                             children
# 0                                                NaN
# 1                                                NaN
# 2  [https://knowyourmeme.com/memes/bitches-dont-k...
# 3                                                NaN
# 4                                                NaN

# %%
data['cleaned_type'] = ""

# Iterate through rows
for index, row in data.iterrows():
    types = row['details'].get('type', [])
    cleaned_types = [t.replace('https://knowyourmeme.com/types/', '') for t in types]
    data.at[index, 'cleaned_type'] = cleaned_types

# Count instances with empty 'cleaned_type'
empty_type_count = sum(len(row['cleaned_type']) == 0 for index, row in data.iterrows())
print(f"Number of entries with 'cleaned_type': {len(data) - empty_type_count}")
print(f"Number of entries with empty 'cleaned_type': {empty_type_count}")

# Remove entries with empty 'cleaned_type'
data = data[data['cleaned_type'].apply(len) > 0]
# Out:
# Number of entries with 'cleaned_type': 2788
# Number of entries with empty 'cleaned_type': 0

# %%
data['cleaned_description'] = ""

# Initialize a variable to store the count of rows with float values
float_rows_count = 0

# Iterate through rows
for index, row in data.iterrows():
    content_value = row['content']

    if isinstance(content_value, dict):
        about_text = content_value.get('about', {}).get('text', [])
        cleaned_description = ' '.join(about_text)  # Combine text into a single string
        data.at[index, 'cleaned_description'] = cleaned_description
    else:
        float_rows_count += 1
        data.at[index, 'cleaned_description'] = ''

# Drop rows where 'content' is of type float
data = data.dropna(subset=['content'])

print(f"Number of rows dropped with float 'content': {float_rows_count}")
data.head()
# Out:
# Number of rows dropped with float 'content': 0
#                                    title  \
# 1                             ROFLcopter
# 2                     Bitches Don't Know
# 7                                   Domo
# 8                         I Like Turtles
# 15  One Does Not Simply Walk Into Mordor
#
#                                                   url  last_update_source  \
# 1           https://knowyourmeme.com/memes/roflcopter          1591400337
# 2    https://knowyourmeme.com/memes/bitches-dont-know          1607986999
# 7                 https://knowyourmeme.com/memes/domo          1609402791
# 8       https://knowyourmeme.com/memes/i-like-turtles          1604343920
# 15  https://knowyourmeme.com/memes/one-does-not-si...          1616091784
#
#    category                                 template_image_url  \
# 1      Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 2      Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 7      Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 8      Meme  https://i.kym-cdn.com/entries/icons/original/0...
# 15     Meme  https://i.kym-cdn.com/entries/icons/original/0...
#
#                                                  meta  \
# 1   {'og:title': 'ROFLcopter', 'og:site_name': 'Kn...
# 2   {'og:title': 'Bitches Don't Know', 'og:site_na...
# 7   {'og:title': 'Domo', 'og:site_name': 'Know You...
# 8   {'og:title': 'I Like Turtles', 'og:site_name':...
# 15  {'og:title': 'One Does Not Simply Walk Into Mo...
#
#                                                    ld         added  \
# 1   {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 2   {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 7   {'@context': 'http://schema.org', '@type': 'Br...  1.231010e+09
# 8   {'@context': 'http://schema.org', '@type': 'Br...  1.229113e+09
# 15  {'@context': 'http://schema.org', '@type': 'Br...  1.239567e+09
#
#                                               details  \
# 1   {'status': 'confirmed', 'origin': 'Warcraft II...
# 2   {'status': 'confirmed', 'origin': 'MySpace', '...
# 7   {'status': 'confirmed', 'origin': 'Newgrounds'...
# 8   {'status': 'confirmed', 'origin': 'KGW News', ...
# 15  {'status': 'confirmed', 'origin': 'Lord of the...
#
#                                               content  \
# 1   {'about': {'text': ['ROFLcopter is an Internet...
# 2   {'about': {'text': ['Bitches Don't Know is an ...
# 7   {'about': {'text': ['Domo is a Japanese charac...
# 8   {'about': {'text': ['"I Like Turtles" is a phr...
# 15  {'about': {'text': ['"One Does Not Simply Walk...
#
#                                                  tags  \
# 1    [ascii, animated gif, rofl, acronym, initialism]
# 2   [myspace, 4chan, parody, know, bitches, dont, ...
# 7   [non-english, copy & paste, photoshop, nhk, ca...
# 8   [newscast, viral videos, catchphrase, jonathan...
# 15  [catchphrase, lotr, fantasy, pop-culture, movi...
#
#                                 additional_references  \
# 1   {'Encyclopedia Dramatica': 'https://encycloped...
# 2   {'Facebook,': 'https://www.facebook.com/search...
# 7   {'Encyclopedia Dramatica,': 'https://encyclope...
# 8   {'Encyclopedia Dramatica': 'https://encycloped...
# 15  {'Dictionary.com,': 'https://www.dictionary.co...
#
#                                search_keywords  \
# 1                                 [roflcopter]
# 2                         [bitches don't know]
# 7   [domo-kun, \u3069\u30fc\u3082\u304f\u3093]
# 8                         [\"i like turtles\"]
# 15  [\"one does not simply walk into mordor\"]
#
#                                                parent  \
# 1            https://knowyourmeme.com/memes/lol-ascii
# 2                                                 NaN
# 7                                                 NaN
# 8         https://knowyourmeme.com/memes/viral-videos
# 15  https://knowyourmeme.com/memes/subcultures/lor...
#
#                                              siblings  \
# 1   [https://knowyourmeme.com/memes/lollerskates, ...
# 2                                                 NaN
# 7                                                 NaN
# 8   [https://knowyourmeme.com/memes/please-give-me...
# 15  [https://knowyourmeme.com/memes/i-summon-you-t...
#
#                                              children  \
# 1                                                 NaN
# 2   [https://knowyourmeme.com/memes/bitches-dont-k...
# 7   [https://knowyourmeme.com/memes/every-time-you...
# 8                                                 NaN
# 15                                                NaN
#
#                                        cleaned_type  \
# 1                                           [slang]
# 2                                     [exploitable]
# 7                                       [character]
# 8                                     [viral-video]
# 15  [catchphrase, pop-culture-reference, snowclone]
#
#                                   cleaned_description
# 1   ROFLcopter is an Internet slang term used as a...
# 2   Bitches Don't Know is an exploitable image mac...
# 7   Domo is a Japanese character often pasted in t...
# 8   "I Like Turtles" is a phrase first uttered by ...
# 15  "One Does Not Simply Walk Into Mordor" (snowcl...

# %%
print(f"Number of rows in the DataFrame after preprocessing: {len(data)}")
# Out:
# Number of rows in the DataFrame after preprocessing: 2788

# %%
import matplotlib.pyplot as plt

# Flatten the 'cleaned_type' lists
all_types = [item for sublist in data['cleaned_type'] for item in sublist]

# Create a DataFrame for counting occurrences
types_df = pd.DataFrame({'type': all_types})

# Plot a histogram
plt.figure(figsize=(10, 6))
types_df['type'].value_counts().plot(kind='bar', color='skyblue')
plt.title('Histogram of Occurrences by Cleaned Type')
plt.xlabel('Cleaned Type')
plt.ylabel('Occurrences')
plt.show()

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.preprocessing import MultiLabelBinarizer
from sklearn.multiclass import OneVsRestClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score, classification_report

# Split the data into training and testing sets
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Convert tags to binary array representation
all_tags = set(tag for tags_list in data['tags'] for tag in tags_list)
mlb = MultiLabelBinarizer(classes=all_tags)
y_train = mlb.fit_transform(train_data['tags'])
y_test = mlb.transform(test_data['tags'])

# Vectorize the cleaned_description using TF-IDF
vectorizer = TfidfVectorizer()
X_train = vectorizer.fit_transform(train_data['cleaned_description'])
X_test = vectorizer.transform(test_data['cleaned_description'])

# Train a Multinomial Naive Bayes classifier using OneVsRest strategy
classifier = OneVsRestClassifier(MultinomialNB())
classifier.fit(X_train, y_train)

# Make predictions on the test set
predictions = classifier.predict(X_test)

# Convert predictions back to tags
predicted_tags = mlb.inverse_transform(predictions)

# Evaluate the model
accuracy = accuracy_score(y_test, predictions)
print(f'Accuracy: {accuracy:.2f}')

# Display classification report
print(classification_report(y_test, predictions))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 15
#      13 all_tags = set(tag for tags_list in data['tags'] for tag in tags_list)
#      14 mlb = MultiLabelBinarizer(classes=all_tags)
# ---> 15 y_train = mlb.fit_transform(train_data['tags'])
#      16 y_test = mlb.transform(test_data['tags'])
#      18 # Vectorize the cleaned_description using TF-IDF
#
# File c:\users\48795\desktop\inzynierka\pyro\research_project\lib\site-packages\sklearn\base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File c:\users\48795\desktop\inzynierka\pyro\research_project\lib\site-packages\sklearn\preprocessing\_label.py:812, in MultiLabelBinarizer.fit_transform(self, y)
#     795 """Fit the label sets binarizer and transform the given label sets.
#     796
#     797 Parameters
#    (...)
#     809     format.
#     810 """
#     811 if self.classes is not None:
# --> 812     return self.fit(y).transform(y)
#     814 self._cached_dict = None
#     816 # Automatically increment on new class
#
# File c:\users\48795\desktop\inzynierka\pyro\research_project\lib\site-packages\sklearn\preprocessing\_label.py:855, in MultiLabelBinarizer.transform(self, y)
#     838 """Transform the given label sets.
#     839
#     840 Parameters
#    (...)
#     851     `y[i]`, and 0 otherwise.
#     852 """
#     853 check_is_fitted(self)
# --> 855 class_to_index = self._build_cache()
#     856 yt = self._transform(y, class_to_index)
#     858 if not self.sparse_output:
#
# File c:\users\48795\desktop\inzynierka\pyro\research_project\lib\site-packages\sklearn\preprocessing\_label.py:865, in MultiLabelBinarizer._build_cache(self)
#     863 def _build_cache(self):
#     864     if self._cached_dict is None:
# --> 865         self._cached_dict = dict(zip(self.classes_, range(len(self.classes_))))
#     867     return self._cached_dict
#
# TypeError: unhashable type: 'set'
